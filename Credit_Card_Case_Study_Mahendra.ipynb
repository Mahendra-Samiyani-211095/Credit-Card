# %%
# Importing the packages5
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importing the data available with us

# %%
File_Path = 'D:\Python class files\Python Assignment\Credit Card Case Study\Case Study 2 - Credit Card Case Study//'
Customer_Data = pd.read_csv(File_Path + 'Customer Acqusition.csv')
Spend_Data = pd.read_csv(File_Path + 'Spend.csv')
Repayment_Data = pd.read_csv(File_Path + 'Repayment.csv')

# %%
# 1st of all We will clean the data and try to understand it's dynamics

# %% [markdown]
# # Customer Dataset

# %%
Customer_Data.head()
# Out:
#    No Customer  Age       City   Product     Limit Company        Segment
# 0   1       A1   76  BANGALORE      Gold  500000.0      C1  Self Employed
# 1   2       A2   71   CALCUTTA    Silver  100000.0      C2   Salaried_MNC
# 2   3       A3   34     COCHIN  Platimum   10000.0      C3   Salaried_Pvt
# 3   4       A4   47     BOMBAY  Platimum   10001.0      C4           Govt
# 4   5       A5   56  BANGALORE  Platimum   10002.0      C5  Normal Salary

# %%
# we will drop the Column with Name 'No'

# %%
Customer_Data.drop(columns = 'No', inplace = True)

# %%
Customer_Data.shape
# Out:
# (100, 7)

# %%
Customer_Data.dtypes
# Out:
# Customer     object
# Age           int64
# City         object
# Product      object
# Limit       float64
# Company      object
# Segment      object
# dtype: object

# %%
Customer_Data.isnull().sum()
# Out:
# Customer    0
# Age         0
# City        0
# Product     0
# Limit       0
# Company     0
# Segment     0
# dtype: int64

# %%
Customer_Data.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of    Customer  Age        City   Product     Limit Company        Segment
# 0        A1   76   BANGALORE      Gold  500000.0      C1  Self Employed
# 1        A2   71    CALCUTTA    Silver  100000.0      C2   Salaried_MNC
# 2        A3   34      COCHIN  Platimum   10000.0      C3   Salaried_Pvt
# 3        A4   47      BOMBAY  Platimum   10001.0      C4           Govt
# 4        A5   56   BANGALORE  Platimum   10002.0      C5  Normal Salary
# ..      ...  ...         ...       ...       ...     ...            ...
# 95      A96   54     CHENNAI    Silver  100000.0     C19   Salaried_Pvt
# 96      A97   58  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 97      A98   51    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 98      A99   35    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 99     A100   36      COCHIN    Silver  100000.0      C5   Salaried_MNC
#
# [100 rows x 7 columns]>

# %% [markdown]
# # Spend Dataset

# %%
Spend_Data.head()
# Out:
#    Sl No: Customer      Month       Type     Amount
# 0       1       A1  12-Jan-04  JEWELLERY  485470.80
# 1       2       A1   3-Jan-04      PETRO  410556.13
# 2       3       A1  15-Jan-04    CLOTHES   23740.46
# 3       4       A1  25-Jan-04       FOOD  484342.47
# 4       5       A1  17-Jan-05     CAMERA  369694.07

# %%
# we will drop the Column with Name 'Sl No:'

# %%
Spend_Data.drop(columns = 'Sl No:', inplace = True)

# %%
Spend_Data.shape
# Out:
# (1500, 4)

# %%
Spend_Data.dtypes
# Out:
# Customer     object
# Month        object
# Type         object
# Amount      float64
# dtype: object

# %%
# Changing the Data Type of 'Month' Column to Datetime Data Type

# %%
Spend_Data.Month = pd.to_datetime(Spend_Data.Month)

# %%
# Checking the Data Type to see the change

# %%
Spend_Data.dtypes
# Out:
# Customer            object
# Month       datetime64[ns]
# Type                object
# Amount             float64
# dtype: object

# %%
Spend_Data.isnull().sum()
# Out:
# Customer    0
# Month       0
# Type        0
# Amount      0
# dtype: int64

# %%
Spend_Data.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of      Customer      Month        Type     Amount
# 0          A1 2004-01-12   JEWELLERY  485470.80
# 1          A1 2004-01-03       PETRO  410556.13
# 2          A1 2004-01-15     CLOTHES   23740.46
# 3          A1 2004-01-25        FOOD  484342.47
# 4          A1 2005-01-17      CAMERA  369694.07
# ...       ...        ...         ...        ...
# 1495      A67 2006-02-04  BUS TICKET  356872.73
# 1496      A68 2006-03-25  BUS TICKET  204971.10
# 1497      A69 2006-03-31  BUS TICKET   50449.44
# 1498      A70 2006-03-23  BUS TICKET   80593.94
# 1499      A71 2006-03-24  BUS TICKET  194447.62
#
# [1500 rows x 4 columns]>

# %% [markdown]
# # Repayment Dataset

# %%
Repayment_Data.head()
# Out:
#    SL No: Customer      Month     Amount  Unnamed: 4
# 0     NaN       A1  12-Jan-04  495414.75         NaN
# 1     2.0       A1   3-Jan-04  245899.02         NaN
# 2     3.0       A1  15-Jan-04  259490.06         NaN
# 3     4.0       A1  25-Jan-04  437555.12         NaN
# 4     5.0       A1  17-Jan-05  165972.88         NaN

# %%
# we will drop the Column with Name 'SL No:' and 'Unnamed: 4'

# %%
Repayment_Data.drop(columns = ['SL No:','Unnamed: 4'], inplace = True)

# %%
Repayment_Data.shape
# Out:
# (1523, 3)

# %%
Repayment_Data.dtypes
# Out:
# Customer     object
# Month        object
# Amount      float64
# dtype: object

# %%
# Changing the Data Type of 'Month' Column to Datetime Data Type

# %%
Repayment_Data.Month = pd.to_datetime(Repayment_Data.Month)

# %%
# Checking the Data Type to see the change

# %%
Repayment_Data.dtypes
# Out:
# Customer            object
# Month       datetime64[ns]
# Amount             float64
# dtype: object

# %%
Repayment_Data.isnull().sum()
# Out:
# Customer    23
# Month       23
# Amount      23
# dtype: int64

# %%
Repayment_Data.dropna(how = 'all' , inplace = True)

# %%
Repayment_Data.shape
# Out:
# (1500, 3)

# %%
Repayment_Data.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of      Customer      Month     Amount
# 0          A1 2004-01-12  495414.75
# 1          A1 2004-01-03  245899.02
# 2          A1 2004-01-15  259490.06
# 3          A1 2004-01-25  437555.12
# 4          A1 2005-01-17  165972.88
# ...       ...        ...        ...
# 1495      A67 2005-05-09   55638.77
# 1496      A68 2006-05-10  319836.49
# 1497      A69 2006-07-11  247628.45
# 1498      A70 2005-08-12  454016.51
# 1499      A71 2004-09-13   56286.33
#
# [1500 rows x 3 columns]>

# %%
# Answer to Question 1 (a)

# %%
# Customers with the age less than 18

# %%
Customer_Data.loc[Customer_Data["Age"] < 18,"Age"]
# Out:
# 13    16
# 40    13
# 62    15
# 67    12
# 69    16
# 89    16
# Name: Age, dtype: int64

# %%
# Average/Mean Age of Customer

# %%
Mean_Age = Customer_Data["Age"].mean()

# %%
print(Mean_Age)
# Out:
# 46.49

# %%
# Replacing the age value with mean where age < 18

# %%
 Customer_Data.loc[Customer_Data["Age"] < 18,"Age"] = Customer_Data["Age"].mean()

# %%
 Customer_Data.head(15)
# Out:
#    Customer    Age       City   Product     Limit Company        Segment
# 0        A1  76.00  BANGALORE      Gold  500000.0      C1  Self Employed
# 1        A2  71.00   CALCUTTA    Silver  100000.0      C2   Salaried_MNC
# 2        A3  34.00     COCHIN  Platimum   10000.0      C3   Salaried_Pvt
# 3        A4  47.00     BOMBAY  Platimum   10001.0      C4           Govt
# 4        A5  56.00  BANGALORE  Platimum   10002.0      C5  Normal Salary
# 5        A6  70.00      DELHI    Silver  100000.0      C6  Self Employed
# 6        A7  26.00     COCHIN    Silver  100001.0      C7   Salaried_MNC
# 7        A8  67.00      PATNA    Silver  100002.0      C8   Salaried_Pvt
# 8        A9  79.00    CHENNAI    Silver  100003.0      C9           Govt
# 9       A10  54.00   CALCUTTA      Gold  500000.0     C10  Normal Salary
# 10      A11  35.00     COCHIN      Gold  500000.0     C11  Normal Salary
# 11      A12  51.00     BOMBAY      Gold  500000.0     C12  Self Employed
# ...

# %%
# We can see the customer A14 whose age was given as 16 has been changed with 46.49 which ensures all customers having age less than 18 has been replaced with mean/average age.

# %%
# Answer to Question - 1 (b)

# %%
# Merging the two table customer and spend table

# %%
Customer_Spend = pd.merge(left=Customer_Data,right=Spend_Data,on="Customer",how="inner")

# %%
Customer_Spend.head()
# Out:
#   Customer   Age       City Product     Limit Company        Segment  \
# 0       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 2       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 3       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 4       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
#
#        Month       Type     Amount
# 0 2004-01-12  JEWELLERY  485470.80
# 1 2004-01-03      PETRO  410556.13
# 2 2004-01-15    CLOTHES   23740.46
# 3 2004-01-25       FOOD  484342.47
# 4 2005-01-17     CAMERA  369694.07

# %%
Customer_Spend.shape
# Out:
# (1500, 10)

# %%
# Customer Data where spend is greater than limit

# %%
High_Spenders = Customer_Spend[Customer_Spend["Amount"] > Customer_Spend['Limit']]

# %%
High_Spenders
# Out:
#      Customer   Age        City   Product     Limit Company        Segment  \
# 18         A2  71.0    CALCUTTA    Silver  100000.0      C2   Salaried_MNC
# 19         A2  71.0    CALCUTTA    Silver  100000.0      C2   Salaried_MNC
# 20         A2  71.0    CALCUTTA    Silver  100000.0      C2   Salaried_MNC
# 21         A2  71.0    CALCUTTA    Silver  100000.0      C2   Salaried_MNC
# 22         A2  71.0    CALCUTTA    Silver  100000.0      C2   Salaried_MNC
# ...       ...   ...         ...       ...       ...     ...            ...
# 1486      A87  27.0    CALCUTTA    Silver  100003.0     C10           Govt
# 1496      A97  58.0  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 1497      A98  51.0    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 1498      A99  35.0    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 1499     A100  36.0      COCHIN    Silver  100000.0      C5   Salaried_MNC
#
#           Month          Type     Amount
# ...

# %%
# Replacing the same with 50% of that customer’s limit.

# %%
High_Spenders = (50 * High_Spenders['Limit']).div(100)

# %%
High_Spenders
# Out:
# 18      50000.0
# 19      50000.0
# 20      50000.0
# 21      50000.0
# 22      50000.0
#          ...
# 1486    50001.5
# 1496     5000.0
# 1497     5000.5
# 1498     5001.0
# 1499    50000.0
# Name: Limit, Length: 607, dtype: float64

# %%
# Answer to Question - 1 (c)

# %%
Repayment_Data.head(1)
# Out:
#   Customer      Month     Amount
# 0       A1 2004-01-12  495414.75

# %%
# merge the two table customer and repay table

# %%
Customer_Repaid = pd.merge(left=Repayment_Data,right=Customer_Data,on='Customer',how='inner')

# %%
Customer_Repaid.head()
# Out:
#   Customer      Month     Amount   Age       City Product     Limit Company  \
# 0       A1 2004-01-12  495414.75  76.0  BANGALORE    Gold  500000.0      C1
# 1       A1 2004-01-03  245899.02  76.0  BANGALORE    Gold  500000.0      C1
# 2       A1 2004-01-15  259490.06  76.0  BANGALORE    Gold  500000.0      C1
# 3       A1 2004-01-25  437555.12  76.0  BANGALORE    Gold  500000.0      C1
# 4       A1 2005-01-17  165972.88  76.0  BANGALORE    Gold  500000.0      C1
#
#          Segment
# 0  Self Employed
# 1  Self Employed
# 2  Self Employed
# 3  Self Employed
# 4  Self Employed

# %%
# Remayment amount greater than Limit

# %%
Customer_Repaid[Customer_Repaid["Amount"] > Customer_Repaid["Limit"]]
# Out:
#      Customer      Month     Amount   Age    City Product     Limit Company  \
# 18         A8 2004-02-05  156913.59  67.0   PATNA  Silver  100002.0      C8
# 19         A8 2004-01-12  350999.98  67.0   PATNA  Silver  100002.0      C8
# 20         A8 2006-03-31  155642.95  67.0   PATNA  Silver  100002.0      C8
# 21         A8 2005-05-09  145457.38  67.0   PATNA  Silver  100002.0      C8
# 22         A8 2006-05-08  361184.89  67.0   PATNA  Silver  100002.0      C8
# ...       ...        ...        ...   ...     ...     ...       ...     ...
# 1494       A7 2006-05-06  400375.97  26.0  COCHIN  Silver  100001.0      C7
# 1496       A7 2005-12-03  429700.12  26.0  COCHIN  Silver  100001.0      C7
# 1497       A7 2005-02-23  344628.72  26.0  COCHIN  Silver  100001.0      C7
# 1498       A7 2006-03-31  336264.37  26.0  COCHIN  Silver  100001.0      C7
# 1499       A7 2004-01-03  473662.61  26.0  COCHIN  Silver  100001.0      C7
#
#            Segment
# 18    Salaried_Pvt
# ...

# %%
# Replace the repayment with the limit.

# %%
Customer_Repaid.loc[Customer_Repaid["Amount"] > Customer_Repaid["Limit"],"Amount"] = Customer_Repaid["Limit"]

# %%
Customer_Repaid
# Out:
#      Customer      Month     Amount   Age       City Product     Limit  \
# 0          A1 2004-01-12  495414.75  76.0  BANGALORE    Gold  500000.0
# 1          A1 2004-01-03  245899.02  76.0  BANGALORE    Gold  500000.0
# 2          A1 2004-01-15  259490.06  76.0  BANGALORE    Gold  500000.0
# 3          A1 2004-01-25  437555.12  76.0  BANGALORE    Gold  500000.0
# 4          A1 2005-01-17  165972.88  76.0  BANGALORE    Gold  500000.0
# ...       ...        ...        ...   ...        ...     ...       ...
# 1495       A7 2005-11-22   55108.71  26.0     COCHIN  Silver  100001.0
# 1496       A7 2005-12-03  100001.00  26.0     COCHIN  Silver  100001.0
# 1497       A7 2005-02-23  100001.00  26.0     COCHIN  Silver  100001.0
# 1498       A7 2006-03-31  100001.00  26.0     COCHIN  Silver  100001.0
# 1499       A7 2004-01-03  100001.00  26.0     COCHIN  Silver  100001.0
#
#      Company        Segment
# 0         C1  Self Employed
# 1         C1  Self Employed
# ...

# %%
# Answer to Question 2 (a)

# %%
Distinct_Customers = Customer_Data["Customer"].nunique()
print("Number of distinct customers are" , Distinct_Customers)
# Out:
# Number of distinct customers are 100

# %%
# Answer to Question - 2 (b)

# %%
Distinct_Category = Customer_Data["Segment"].nunique()
print("Number of distinct categories are" , Distinct_Category)
# Out:
# Number of distinct categories are 5

# %%
# Answer to Question - 2 (c)

# %%
Spend_Data.head()
# Out:
#   Customer      Month       Type     Amount
# 0       A1 2004-01-12  JEWELLERY  485470.80
# 1       A1 2004-01-03      PETRO  410556.13
# 2       A1 2004-01-15    CLOTHES   23740.46
# 3       A1 2004-01-25       FOOD  484342.47
# 4       A1 2005-01-17     CAMERA  369694.07

# %%
Spend_Data['Month No.'] = pd.DatetimeIndex(Spend_Data['Month']).month
Spend_Data['Year'] = pd.DatetimeIndex(Spend_Data['Month']).year
Spend_Data.head()
# Out:
#   Customer      Month       Type     Amount  Month No.  Year
# 0       A1 2004-01-12  JEWELLERY  485470.80          1  2004
# 1       A1 2004-01-03      PETRO  410556.13          1  2004
# 2       A1 2004-01-15    CLOTHES   23740.46          1  2004
# 3       A1 2004-01-25       FOOD  484342.47          1  2004
# 4       A1 2005-01-17     CAMERA  369694.07          1  2005

# %%
Average_Momthly_Spent = round(Spend_Data.groupby(['Month No.','Year']).mean(),2)
print(Average_Momthly_Spent)
# Out:
#                    Amount
# Month No. Year
# 1         2004  251712.07
#           2005  292741.37
#           2006  282058.01
# 2         2004  221215.27
#           2005  229802.28
#           2006  253858.26
# 3         2004  232146.12
#           2006  247166.08
# 4         2004  235272.04
#           2005  252181.33
#           2006  232468.97
# 5         2004  217539.24
#           2005  245696.52
#           2006  236162.74
# 6         2005  262688.11
#           2006  177252.39
# 7         2005  229116.66
#           2006  287505.10
# 8         2005  233734.63
#           2006  240699.72
# 9         2004  310923.38
#           2005  188666.20
#           2006  158520.09
# 10        2005  194568.64
#           2006  236136.34
# 11        2004  270486.40
#           2005  286143.32
#           2006  182841.29
# 12        2005  147503.06
#           2006  270470.98

# %%
# Answer to Question - 2(d)

# %%
Repayment_Data.head()
# Out:
#   Customer      Month     Amount
# 0       A1 2004-01-12  495414.75
# 1       A1 2004-01-03  245899.02
# 2       A1 2004-01-15  259490.06
# 3       A1 2004-01-25  437555.12
# 4       A1 2005-01-17  165972.88

# %%
Repayment_Data['Month No.'] = pd.DatetimeIndex(Repayment_Data['Month']).month
Repayment_Data['Year'] = pd.DatetimeIndex(Repayment_Data['Month']).year
Repayment_Data.head()
# Out:
#   Customer      Month     Amount  Month No.  Year
# 0       A1 2004-01-12  495414.75          1  2004
# 1       A1 2004-01-03  245899.02          1  2004
# 2       A1 2004-01-15  259490.06          1  2004
# 3       A1 2004-01-25  437555.12          1  2004
# 4       A1 2005-01-17  165972.88          1  2005

# %%
Average_Momthly_Repayment = round(Repayment_Data.groupby(['Month No.' , 'Year']).mean(),2)
print(Average_Momthly_Repayment)
# Out:
#                    Amount
# Month No. Year
# 1         2004  243489.65
#           2005  240548.10
#           2006  293475.39
# 2         2004  256702.63
#           2005  238829.27
#           2006  284489.57
# 3         2004  252585.28
#           2006  240851.27
# 4         2004  259141.68
#           2005  212688.63
#           2006  275472.25
# 5         2004  226162.72
#           2005  263207.37
#           2006  256920.88
# 6         2005  210199.82
#           2006  251990.45
# 7         2005  239871.48
#           2006  257936.38
# 8         2005  264430.92
#           2006  224143.99
# 9         2004  184487.85
#           2005  247700.17
#           2006  262533.88
# 10        2005  219849.96
#           2006  260765.48
# 11        2004  209592.24
#           2005  256695.12
#           2006  199399.20
# 12        2005  320379.34
#           2006  252736.57

# %%
# Answer to Question 2 (e)

# %%
# Merging the 'Customer Dataset', 'Spend Dataset' and 'Repayment Dataset'

# %%
Customer_Spend_Data = pd.merge(left = Customer_Data, right = Spend_Data, on = "Customer", how = "inner")

# %%
Customer_Spend_Data
# Out:
#      Customer   Age        City   Product     Limit Company        Segment  \
# 0          A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 1          A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 2          A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 3          A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 4          A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# ...       ...   ...         ...       ...       ...     ...            ...
# 1495      A96  54.0     CHENNAI    Silver  100000.0     C19   Salaried_Pvt
# 1496      A97  58.0  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 1497      A98  51.0    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 1498      A99  35.0    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 1499     A100  36.0      COCHIN    Silver  100000.0      C5   Salaried_MNC
#
#           Month        Type     Amount  Month No.  Year
# ...

# %%
Data = pd.merge(left = Customer_Spend_Data, right = Repayment_Data, on = "Customer", how = "inner")

# %%
Data
# Out:
#       Customer   Age        City   Product     Limit Company        Segment  \
# 0           A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 1           A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 2           A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 3           A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 4           A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# ...        ...   ...         ...       ...       ...     ...            ...
# 37279      A96  54.0     CHENNAI    Silver  100000.0     C19   Salaried_Pvt
# 37280      A97  58.0  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 37281      A98  51.0    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 37282      A99  35.0    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 37283     A100  36.0      COCHIN    Silver  100000.0      C5   Salaried_MNC
#
# ...

# %%
Intrest = Data.groupby(["Month_x", "Month_y"])["Amount_x","Amount_y"].sum()
# Out:
# C:\Users\s\AppData\Local\Temp\ipykernel_11848\2067999024.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   Intrest = Data.groupby(["Month_x", "Month_y"])["Amount_x","Amount_y"].sum()

# %%
Intrest
# Out:
#                           Amount_x     Amount_y
# Month_x    Month_y
# 2004-01-03 2004-01-03  24011634.61  26266651.80
#            2004-01-12  24317033.23  27036939.32
#            2004-01-15  26639115.85  26692176.23
#            2004-01-25  24215687.28  20176959.91
#            2004-02-05   8588861.13   9212834.97
# ...                            ...          ...
# 2006-12-03 2006-09-03   1027544.81   1476707.54
#            2006-10-03    226412.38    234343.03
#            2006-11-03    982455.71    804832.05
#            2006-11-21   1186828.88    726917.54
#            2006-12-03   1133438.59    909860.79
#
# [5388 rows x 2 columns]

# %%
Intrest["Monthly_Profit"] = Intrest["Amount_y"] - Intrest["Amount_x"]

# %%
Intrest.head(15)
# Out:
#                           Amount_x     Amount_y  Monthly_Profit
# Month_x    Month_y
# 2004-01-03 2004-01-03  24011634.61  26266651.80      2255017.19
#            2004-01-12  24317033.23  27036939.32      2719906.09
#            2004-01-15  26639115.85  26692176.23        53060.38
#            2004-01-25  24215687.28  20176959.91     -4038727.37
#            2004-02-05   8588861.13   9212834.97       623973.84
#            2004-03-19   3790831.53   4492192.16       701360.63
#            2004-04-06   4758108.43   3143380.92     -1614727.51
#            2004-04-25   5426593.69   8077396.83      2650803.14
#            2004-05-05  10383832.49   7631673.34     -2752159.15
#            2004-09-13   7300919.36   5229555.78     -2071363.58
#            2004-11-23   5361450.39   4810592.00      -550858.39
#            2005-01-17   9336295.09  10364375.85      1028080.76
#            2005-02-01   7414588.13   7292700.92      -121887.21
# ...

# %%
Net_Profit = Intrest["Monthly_Profit"].sum()

# %%
Intrest['Profit_Intrest'] = (2.9* Intrest["Monthly_Profit"] )/100

# %%
Intrest.head(15)
# Out:
#                           Amount_x     Amount_y  Monthly_Profit  \
# Month_x    Month_y
# 2004-01-03 2004-01-03  24011634.61  26266651.80      2255017.19
#            2004-01-12  24317033.23  27036939.32      2719906.09
#            2004-01-15  26639115.85  26692176.23        53060.38
#            2004-01-25  24215687.28  20176959.91     -4038727.37
#            2004-02-05   8588861.13   9212834.97       623973.84
#            2004-03-19   3790831.53   4492192.16       701360.63
#            2004-04-06   4758108.43   3143380.92     -1614727.51
#            2004-04-25   5426593.69   8077396.83      2650803.14
#            2004-05-05  10383832.49   7631673.34     -2752159.15
#            2004-09-13   7300919.36   5229555.78     -2071363.58
#            2004-11-23   5361450.39   4810592.00      -550858.39
#            2005-01-17   9336295.09  10364375.85      1028080.76
#            2005-02-01   7414588.13   7292700.92      -121887.21
# ...

# %%
Net_Profit_Intrest = Intrest["Profit_Intrest"].sum()
print(Net_Profit_Intrest)
# Out:
# 5466918.6280499995

# %%
# Answer to Question 2 (f)

# %%
Spend_Data["Type"].value_counts().head(5)
# Out:
# PETRO           200
# FOOD            160
# CAMERA          160
# AIR TICKET      147
# TRAIN TICKET    132
# Name: Type, dtype: int64

# %%
# Answer to Question 2(g)

# %%
Spend_by_City = Customer_Spend_Data.groupby("City")["Amount"].sum()
print("City with maximum spend", Spend_by_City.sort_values(ascending=False).head(1))
# Out:
# City with maximum spend City
# COCHIN    73495349.26
# Name: Amount, dtype: float64

# %%
# Anser to Question 2 (h)

# %%
Customer_Spend_Data.head()
Spend_by_City = Customer_Spend_Data.groupby("Age")["Amount"].sum()
print("Age Group with maximum spend", Spend_by_City.sort_values(ascending=False).head(1))
# Out:
# Age Group with maximum spend Age
# 28.0    25098877.03
# Name: Amount, dtype: float64

# %%
# Answer to Question 2 (i)

# %%
Customer_Repayment = pd.merge(left = Customer_Data, right = Repayment_Data, on = "Customer", how = "inner")

# %%
Customer_Repayment.head()
Top_customer_Repaid = Customer_Repayment.groupby("Customer")["Amount"].sum()
print("Top 10 customers in terms of repayment", Top_customer_Repaid.sort_values(ascending=False).head(10))
# Out:
# Top 10 customers in terms of repayment Customer
# A61    10539142.91
# A60     9876290.74
# A13     9572000.66
# A22     9372561.68
# A21     9056336.15
# A43     8489871.46
# A45     8448334.87
# A12     8334760.16
# A48     8292416.75
# A14     7943268.63
# Name: Amount, dtype: float64

# %%
# Answer to Question 3

# %%
Customer_Spend_Pivot = pd.pivot_table(data = Customer_Spend_Data, index = ["City","Year"], columns = 'Product', aggfunc = "sum", values = "Amount")

# %%
Customer_Spend_Pivot
# Out:
# Product                 Gold     Platimum      Silver
# City       Year
# BANGALORE  2004   9289878.54   6046763.93  6773901.65
#            2005  12892362.99   7784194.68  3936068.22
#            2006  12030611.09   5620904.86  4967945.66
# BOMBAY     2004   6987853.53   5199581.00  3061805.08
#            2005   8983018.28   5134074.48  2368375.97
#            2006   7917144.31   7547549.72  3628864.37
# CALCUTTA   2004   7477140.98   5961165.93  3321963.10
#            2005  10303355.80   8810284.03  1285609.11
#            2006  11167532.77  11305526.03  4783182.26
# CHENNAI    2004   1059618.50   5558572.68  1156129.37
#            2005   3740945.58   8868435.43  1000540.48
#            2006   2704288.62   6921130.79  1665326.62
# COCHIN     2004   7315850.15   8472832.23  4587738.70
#            2005  12110613.03  10856722.82  2619231.25
#            2006  10499142.38  12453968.83  4579249.87
# DELHI      2004   2806495.00   1565199.90  4293224.28
# ...

# %%
# Answer to Question 4 (a)

# %%
Customer_Spend_Data['Month_Name'] = Customer_Spend_Data['Month'].apply(lambda x:pd.Timestamp.strftime(x,format="%B"))

# %%
Customer_Spend_Data
# Out:
#      Customer   Age        City   Product     Limit Company        Segment  \
# 0          A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 1          A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 2          A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 3          A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 4          A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# ...       ...   ...         ...       ...       ...     ...            ...
# 1495      A96  54.0     CHENNAI    Silver  100000.0     C19   Salaried_Pvt
# 1496      A97  58.0  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 1497      A98  51.0    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 1498      A99  35.0    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 1499     A100  36.0      COCHIN    Silver  100000.0      C5   Salaried_MNC
#
#           Month        Type     Amount  Month No.  Year Month_Name
# ...

# %%
Spend_by_Month = Customer_Spend_Data.groupby(["Month_Name","City"])[["Amount"]].sum().sort_index().reset_index()

# %%
Spend_by_Month = pd.pivot_table(data = Customer_Spend_Data, values = 'Amount', index = 'City', columns = 'Month_Name', aggfunc = 'sum')

# %%
Spend_by_Month
# Out:
# Month_Name       April      August    December     February      January  \
# City
# BANGALORE   6182081.72  1552898.45   722473.97   9875860.87  17782487.66
# BOMBAY      3726382.34  1066744.75   604939.17   7813534.61  10681854.60
# CALCUTTA    6883832.96  2179294.85   456826.68  11449586.70  14163384.38
# CHENNAI     3231144.38   681577.16   223628.27   5866408.35   7649568.68
# COCHIN      7070107.83  2582997.08  2011774.32   9459367.08  18692606.60
# DELHI       2845176.75   475893.81   967169.49   3072043.85   7373794.37
# PATNA       2786278.83   813559.15   223902.41   3466726.76   7388720.78
# TRIVANDRUM  2775772.32   561400.55   640922.26   4459329.30   5688758.54
#
# Month_Name        July        June        March          May    November  \
# City
# BANGALORE   3737413.09  1382739.41  10765773.46  10743668.90  3435745.65
# BOMBAY       612457.59  1486412.18   9857699.82   6974931.87  5120665.55
# CALCUTTA    2323261.43  2693423.54  10076115.86   7868030.30  3490771.91
# ...

# %%
Spend_by_Month.plot(kind="bar",figsize=(18,5),width=0.6)
plt.show()

# %%
# Answer to Question 4 (b)

# %%
Air_Ticket_Spend = Customer_Spend_Data.groupby(["Year","Type"])[["Amount"]].sum().reset_index()

# %%
Filtered_Air_Type = Air_Ticket_Spend.loc[Air_Ticket_Spend["Type"] == "AIR TICKET"]

# %%
Filtered_Air_Type
# Out:
#     Year        Type       Amount
# 0   2004  AIR TICKET   8370914.59
# 15  2005  AIR TICKET  14495718.73
# 30  2006  AIR TICKET  10088812.10

# %%
plt.bar(Filtered_Air_Type["Year"], height = Filtered_Air_Type["Amount"])
plt.xlabel("Year")
plt.ylabel("Amount Spent")
plt.title("Comparison of yearly spend on air tickets")
plt.show()

# %%
# Answer to Question 4 (c)

# %%
Product = pd.pivot_table(data = Customer_Spend_Data, index = 'Product', columns = 'Month_Name', values = 'Amount', aggfunc = 'sum')

# %%
Product
# Out:
# Month_Name        April      August    December     February      January  \
# Product
# Gold        13170572.59  4954030.42  2332940.96  24779179.55  32413831.83
# Platimum    12798498.34  3892605.15  2951972.85  22081411.74  35212526.96
# Silver       9531706.20  1067730.23   566722.76   8602266.23  21794816.82
#
# Month_Name        July        June        March          May    November  \
# Product
# Gold        5167416.37  6538862.64  19256972.48  21548169.76  9203267.46
# Platimum    3695098.37  4756418.62  22639437.70  19380600.97  7977852.48
# Silver      2395261.32  2219152.89  14988675.86   9739404.20  3743265.31
#
# Month_Name     October   September
# Product
# Gold        3018223.38  3816887.62
# Platimum    2517051.91  3411278.13
# Silver       494594.37  1985369.72

# %%
Product.plot(kind = "bar", figsize = (18,6), width=0.8)
plt.ylabel("Amount Spend")
plt.title("monthly spent amount on different products")
plt.show()

# %%
# Seasonality
# From above we can see seasonality starts from Jan t0 May , and Jan month having highest sales

# %%
# Answer to Question 5

# %%
Customer_Repayment['Month_Name'] = Customer_Repayment['Month'].apply(lambda x:pd.Timestamp.strftime(x,format="%B"))
Customer_Repayment['Year'] = Customer_Repayment['Month'].apply(lambda x:pd.Timestamp.strftime(x,format="%Y"))

# %%
def summary_report(product,timeperiod):
    print('Give the product name and timeperiod for which you want the data')
    if product.lower()=='gold' and timeperiod.lower() =='Month_Name':
        pivot = Customer_Repayment.pivot_table(index=['Product','City','Customer'],columns ='Month_Name',aggfunc='sum',values='Amount')
        result = pivot.loc[('Gold',['BANGALORE','COCHIN','CALCUTTA','BOMBAY','CHENNAI','TRIVANDRUM','PATNA','DELHI']),:]
    elif product.lower()=='gold' and timeperiod.lower()=='Year':
        pivot = Customer_Repayment.pivot_table(index=['Product','City','Customer'],columns='Year',aggfunc='sum',values='Amount')
        result = pivot.loc[('Gold',['BANGALORE','COCHIN','CALCUTTA','BOMBAY','CHENNAI','TRIVANDRUM','PATNA','DELHI']),:]
    elif product.lower()=='silver' and timeperiod.lower()=='Month_Name':
        pivot = Customer_Repayment.pivot_table(index=['Product','City','Customer'],columns='Month_Name',aggfunc='sum',values='Amount')
        result = pivot.loc[('Silver',['BANGALORE','COCHIN','CALCUTTA','BOMBAY','CHENNAI','TRIVANDRUM','PATNA','DELHI']),:]
    elif product.lower()=='silver' and timeperiod.lower()=='Year':
        pivot = Customer_Repayment.pivot_table(index=['Product','City','Customer'],columns='Year',aggfunc='sum',values='Amount')
        result = pivot.loc[('Silver',['BANGALORE','COCHIN','CALCUTTA','BOMBAY','CHENNAI','TRIVANDRUM','PATNA','DELHI']),:]
    if product.lower()=='platinum' and timeperiod.lower()=='Month_Name':
        pivot = Customer_Repayment.pivot_table(index=['Product','City','Customer'],columns='Month_Name',aggfunc='sum',values='Amount')
        result = pivot.loc[('Platinum',['BANGALORE','COCHIN','CALCUTTA','BOMBAY','CHENNAI','TRIVANDRUM','PATNA','DELHI']),:]
    elif product.lower()=='platinum' and timeperiod.lower()=='Year':
        pivot = Customer_Repayment.pivot_table(index=['Product','City','Customer'],columns='Year',aggfunc='sum',values='Amount')
        result = pivot.loc[('Platinum',['BANGALORE','COCHIN','CALCUTTA','BOMBAY','CHENNAI','TRIVANDRUM','PATNA','DELHI']),:]
    return result
